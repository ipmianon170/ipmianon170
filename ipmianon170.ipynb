# %% [markdown]
# # Demo for IPMI submission 170
#
# Please run the cells of this jupyter (`Runtime > Run all`)
# and explore the model in the last cell.

# %% [markdown]
# ### Install dependencies and import

# %%
# !pip install matplotlib numpy tensorflow-gpu
# !pip install --upgrade git+https://github.com/ipmianon170/ipmianon170.git

# %%
# %matplotlib notebook
from ipywidgets import *
import hm

# %% [markdown]
# ### Load pretrained model and data

# %% [markdown]
# Setup interaction and interact

# %%
interactor = hm.HyperMorphInteractiveWindow()
interact(interactor.update, h=(0.0, 1.0, 0.01));
# Out:
# <img src="data:image/png;base64,..." width="1200">
# interactive(children=(FloatSlider(value=0.5, description='h', max=1.0), Output()), _dom_classes=('widget-inter…
